# %% [markdown]
# # Explore `train` dataset
# This notebook loads `data/train.csv` and shows quick EDA outputs; click the table outputs to open the Data Viewer.

# %%
import pandas as pd
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 100)
train = pd.read_csv('./data/train.csv')

# %%
# Show the first rows
train.head()

# %%
# DataFrame info
train.info()

# %%
# Summary statistics
train.describe(include='all')

# %%
# Random sample for inspection
train.sample(50)
